# %% [markdown]
# <a href="https://colab.research.google.com/github/lizihan-buaa/cuda_study/blob/main/%E6%AC%A2%E8%BF%8E%E4%BD%BF%E7%94%A8_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# 挂载后，你可以将文件保存到 /content/drive/MyDrive/ 目录下，这样就不会丢失了。

# %%
from google.colab import files

# 假设您想保存的文件名是 'test.cu'
# files.download('test.cu')
